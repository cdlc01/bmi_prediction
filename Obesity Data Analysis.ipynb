# %%
import pandas as pd
import numpy as np

from statistics import mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier
from lazypredict.Supervised import LazyRegressor
# Out:
# /Users/christopherdelacruz/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv('ObesityDataSet.csv')

# %%
df['BMI'] = df['Weight']/(df['Height']**2)

# %%
fixed_df = df.drop(['Height', 'Weight'], axis = 1)

# %% [markdown]
# # Data Analysis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()

gen_x = ['Male', 'Female']
gen_y = [1068, 1043]

ax.bar(gen_x, gen_y)
ax.set_title('# of Male Participants v. # of Female Participants')
ax.set_ylabel('# of Participants')
plt.grid();

# %%
fig1, ax1 = plt.subplots()

z = fixed_df['Age'].values

ax1.hist(z, edgecolor = 'black', bins = 20)
ax1.set_title(f'''Distribution of Age of Participants 
Mean = {round(np.mean(z), 2)} | Median = {round(np.median(z), 2)} | Mode = {round(mode(z), 2)}''')
ax1.set_ylabel('# of Participants')
ax1.set_xlabel('Age')
plt.grid();

# %%
fig2, ax2 = plt.subplots()

fam_x = fixed_df['family_history_with_overweight'].value_counts().index
fam_y = fixed_df['family_history_with_overweight'].value_counts().values

ax2.bar(fam_x, fam_y)
ax2.set_title(f'# of Participants with Family History of Overweight v. No Family History')
ax2.set_ylabel('# of Participants')
plt.grid();

# %%
fig3, ax3 = plt.subplots()

cal_x = fixed_df['FAVC'].value_counts().index
cal_y = fixed_df['FAVC'].value_counts().values

ax3.bar(cal_x, cal_y)
ax3.set_title('# of Participants Who Eat High Caloric Food Frequently')
ax3.set_ylabel('# of Participants')
plt.grid();

# %%
fig4, ax4 = plt.subplots()

z2 = fixed_df['FCVC']

ax4.hist(z2, edgecolor = 'black', bins = 20)
ax4.set_title(f'''Frequency of Consumption of Vegetables 
Mean = {round(np.mean(z2), 2)} | Median = {round(np.median(z2), 2)} | Mode = {round(mode(z2), 2)}''')
ax4.set_ylabel('Frequency')
ax4.set_xlabel('Frequency of Consumption of Vegetables')
plt.grid();

# %%
fig5, ax5 = plt.subplots()

z3 = fixed_df['NCP']

ax5.hist(z3, edgecolor = 'black', bins = 20)
ax5.set_title(f'''# of Main Meals 
Mean = {round(np.mean(z3), 2)} | Median = {round(np.median(z3), 2)} | Mode = {round(mode(z3), 2)}''')
ax5.set_ylabel('Frequency')
ax5.set_xlabel('# of Main Meals')
plt.grid();

# %%
fig6, ax6 = plt.subplots()

con_x = fixed_df['CAEC'].value_counts().index
con_y = fixed_df['CAEC'].value_counts().values

ax6.bar(con_x, con_y)
ax6.set_title('# of Participants Who Consume Food Between Meals')
ax6.set_ylabel('# of Participants')
plt.grid();

# %%
fig7, ax7 = plt.subplots()

smoke_x = fixed_df['SMOKE'].value_counts().index
smoke_y = fixed_df['SMOKE'].value_counts().values

ax7.bar(smoke_x, smoke_y)
ax7.set_title('# of Participants Who Smoke')
ax7.set_ylabel('# of Participants')
plt.grid();

# %%
fig8, ax8 = plt.subplots()

z4 = fixed_df['CH2O']

ax8.hist(z4, edgecolor = 'black', bins = 20)
ax8.set_title(f'''Consumption of Water Daily in Liters 
Mean = {round(np.mean(z4), 2)} | Median = {round(np.median(z4), 2)} | Mode = {round(mode(z4), 2)}''')
ax8.set_ylabel('Frequency')
ax8.set_xlabel('Liters of Water Consumed Daily')
plt.grid();

# %%
fig9, ax9 = plt.subplots()

mon_x = fixed_df['SCC'].value_counts().index
mon_y = fixed_df['SCC'].value_counts().values

ax9.bar(mon_x, mon_y)
ax9.set_title('# of Participants Who Monitor Calorie Consumption')
ax9.set_ylabel('# of Participants')
plt.grid();

# %%
fig10, ax10 = plt.subplots()

z5 = fixed_df['FAF']

ax10.hist(z5, edgecolor = 'black', bins = 20)
ax10.set_title(f'''Frequency of Physical Activity 
Mean = {round(np.mean(z5), 2)} | Median = {round(np.median(z5), 2)} | Mode = {round(mode(z5), 2)}''')
ax10.set_ylabel('Frequency')
ax10.set_xlabel('Physical Activity Frequency')
plt.grid();

# %%
fig11, ax11 = plt.subplots()

z6 = fixed_df['TUE']

ax11.hist(z6, edgecolor = 'black', bins = 20)
ax11.set_title(f'''Amount of Time Using Technology Devices 
Mean = {round(np.mean(z6), 2)} | Median = {round(np.median(z6), 2)} | Mode = {round(mode(z6), 2)}''')
ax11.set_ylabel('Frequency')
ax11.set_xlabel('Time on Technology Devices')
plt.grid();

# %%
fig12, ax12 = plt.subplots()

alc_x = fixed_df['CALC'].value_counts().index
alc_y = fixed_df['CALC'].value_counts().values

ax12.bar(alc_x, alc_y)
ax12.set_title('Alcohol Consumption')
ax12.set_ylabel('# of Participants')
plt.grid();

# %%
fig13, ax13 = plt.subplots()

tra_x = fixed_df['MTRANS'].value_counts().index
tra_y = fixed_df['MTRANS'].value_counts().values

ax13.bar(tra_x, tra_y)
ax13.set_title('Different Types of Transportation Used')
ax13.set_ylabel('# of Participants')
plt.grid()
plt.xticks(rotation = 25);

# %%
fig14, ax14 = plt.subplots()

nob_x = fixed_df['NObeyesdad'].value_counts().index
nob_y = fixed_df['NObeyesdad'].value_counts().values

ax14.bar(nob_x, nob_y)
ax14.set_title('BMI Classification')
ax14.set_ylabel('# of Participants')
plt.grid()
plt.xticks(rotation = 45);

# %%
fig15, ax15 = plt.subplots()

z7 = fixed_df['BMI']

ax15.hist(z7, edgecolor = 'black', bins = 20)
ax15.set_title(f'''BMI
Mean = {round(np.mean(z7), 2)} | Median = {round(np.median(z7), 2)} | Mode = {round(mode(z7), 2)}''')
ax15.set_ylabel('Frequency')
ax15.set_xlabel('BMI')
plt.grid();

# %% [markdown]
# # Lazy Predict Regression

# %%
reg = fixed_df

# %%
SS = StandardScaler()

# %%
cat = ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']
cont = ['Age', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE', 'BMI']
ed = ['Age', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

# %%
reg = pd.concat([pd.get_dummies(reg[cat]), reg[cont]], axis = 1)

# %%
X = reg.drop(['BMI'], axis = 1)
y = reg['BMI']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train[ed] = SS.fit_transform(X_train[ed])

# %%
X_test[ed] = SS.transform(X_test[ed])

# %%
lzy_reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)

# %%
models, predictions = lzy_reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:11<00:00,  3.71it/s]

# %%
print(models)
# Out:
#                                Adjusted R-Squared  R-Squared   RMSE  \
# Model
# RandomForestRegressor                        0.88       0.88   2.86
# LGBMRegressor                                0.87       0.88   2.89
# HistGradientBoostingRegressor                0.87       0.88   2.95
# ExtraTreesRegressor                          0.87       0.88   2.96
# BaggingRegressor                             0.87       0.87   2.97
# XGBRegressor                                 0.85       0.86   3.13
# KNeighborsRegressor                          0.83       0.84   3.31
# MLPRegressor                                 0.79       0.81   3.70
# ExtraTreeRegressor                           0.79       0.80   3.74
# DecisionTreeRegressor                        0.78       0.79   3.81
# GradientBoostingRegressor                    0.77       0.79   3.88
# SVR                                          0.75       0.77   4.04
# NuSVR                                        0.74       0.76   4.13
# ...

# %% [markdown]
# # Lazy Predict Classification

# %%
lazc = reg.drop(['BMI'], axis = 1)

# %%
lazc['NObeyesdad'] = fixed_df['NObeyesdad']

# %%
X2 = lazc.drop(['NObeyesdad'], axis = 1)
y2 = lazc['NObeyesdad']

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, random_state=0)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)

# %%
models2,predictions2 = clf.fit(X_train2, X_test2, y_train2, y_test2)
# Out:
# 100%|██████████| 29/29 [00:14<00:00,  2.00it/s]

# %%
print(models2)
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.87               0.86    None      0.87
# ExtraTreesClassifier               0.84               0.83    None      0.84
# XGBClassifier                      0.84               0.83    None      0.83
# LGBMClassifier                     0.83               0.82    None      0.83
# BaggingClassifier                  0.82               0.81    None      0.82
# LabelPropagation                   0.78               0.77    None      0.78
# LabelSpreading                     0.78               0.77    None      0.78
# KNeighborsClassifier               0.75               0.74    None      0.75
# SVC                                0.74               0.73    None      0.74
# DecisionTreeClassifier             0.74               0.73    None      0.74
# ExtraTreeClassifier                0.74               0.73    None      0.74
# ...
